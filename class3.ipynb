# %% [markdown]
# <a href="https://colab.research.google.com/github/oskarsah/107-2Multimedia/blob/master/class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

#主函數
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG', cv2.IMREAD_COLOR)
# plt.imshow(image2)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG', 0)
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[254, 254, 255, ..., 238, 236, 239],
#        [255, 255, 255, ..., 238, 234, 235],
#        [255, 255, 255, ..., 238, 235, 236],
#        ...,
#        [150, 150, 147, ..., 111, 105, 107],
#        [148, 149, 148, ..., 106, 111, 105],
#        [157, 152, 148, ..., 110, 113, 114]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG')
b,g,r = cv2.split(image6)#slow
img = cv2.merge((r,g,b))#slow
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
