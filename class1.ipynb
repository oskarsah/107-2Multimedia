# %% [markdown]
# <a href="https://colab.research.google.com/github/oskarsah/107-2Multimedia/blob/master/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
import sys

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls /content/drive/My\ Drive/107-2Multimedia
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# DSC_0030.JPG  DSC_0280.JPG

# %%
from matplotlib import pyplot as plt

# %%
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/DSC_0030.JPG', cv2.IMREAD_ANYCOLOR)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)#
  else:
    print("Usge:python firstOpenCV3.py imageFile")
  #cv2.imshow("image",image)
  #cv2.waitKey(0)
  #cv2.destroyAllWindows()
  plt.imshow(image)
  plt.show()

# %%
image.shape
# Out:
# (1920, 1088, 3)
